# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav29py/Data_Analyst/blob/main/Project_uberdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/uberdrive.csv',encoding='ISO-8859-1')
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.head(11)
# Out:
#          START_DATE*         END_DATE* CATEGORY*           START*  \
# 0   01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1   01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2   01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3   01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4   01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5   01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6   01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7   01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8   01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9   01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
# 10  01-10-2016 15:08  01-10-2016 15:51  Business         New York
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# ...

# %%
df.tail(11)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1145           Karachi      2.8  Errand/Supplies
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
d={'START_DATE*':'START_TIME','END_DATE*':'END_TIME','CATEGORY*':'CATEGORY','START*':'START','STOP*':'STOP','MILES*':'KM','PURPOSE*':'PURPOSE'}
df.rename(columns=d,inplace=True)
df
# Out:
#             START_TIME          END_TIME  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP       KM          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#change Datatime
df["STARTING_DATETIME"]=pd.to_datetime(df['START_TIME'],format='mixed', errors = 'coerce')
df
# Out:
#             START_TIME          END_TIME  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP       KM          PURPOSE   STARTING_DATETIME
# 0          Fort Pierce      5.1   Meal/Entertain 2016-01-01 21:11:00
# ...

# %%
df['STARTING_TIME']=df['STARTING_DATETIME'].dt.time     #dt is an accessor or to extract the particular component like (year,time,hour) before using dt.(attribute) we need datetime column.
df['DATE']=df['STARTING_DATETIME'].dt.date
df
# Out:
#             START_TIME          END_TIME  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP       KM          PURPOSE   STARTING_DATETIME  \
# ...

# %%
df["end"]=pd.to_datetime(df['END_TIME'],format='mixed', errors = 'coerce')
df
df['END_TIME']=df['end'].dt.time     #dt is an accessor or to extract the particular component like (year,time,hour) before using dt.(attribute) we need datetime column.
df
# Out:
#             START_TIME  END_TIME  CATEGORY             START  \
# 0     01-01-2016 21:11  21:17:00  Business       Fort Pierce
# 1     01-02-2016 01:25  01:37:00  Business       Fort Pierce
# 2     01-02-2016 20:25  20:38:00  Business       Fort Pierce
# 3     01-05-2016 17:31  17:45:00  Business       Fort Pierce
# 4     01-06-2016 14:42  15:49:00  Business       Fort Pierce
# ...                ...       ...       ...               ...
# 1151  12/31/2016 13:24  13:42:00  Business           Karachi
# 1152  12/31/2016 15:03  15:38:00  Business  Unknown Location
# 1153  12/31/2016 21:32  21:50:00  Business        Katunayake
# 1154  12/31/2016 22:08  23:51:00  Business           Gampaha
# 1155            Totals       NaT       NaN               NaN
#
#                   STOP       KM          PURPOSE   STARTING_DATETIME  \
# 0          Fort Pierce      5.1   Meal/Entertain 2016-01-01 21:11:00
# 1          Fort Pierce      5.0              NaN 2016-01-02 01:25:00
# ...

# %%
df.drop(['START_TIME','end','STARTING_DATETIME'],axis=1,inplace=True)
df
# Out:
#       END_TIME  CATEGORY             START              STOP       KM  \
# 0     21:17:00  Business       Fort Pierce       Fort Pierce      5.1
# 1     01:37:00  Business       Fort Pierce       Fort Pierce      5.0
# 2     20:38:00  Business       Fort Pierce       Fort Pierce      4.8
# 3     17:45:00  Business       Fort Pierce       Fort Pierce      4.7
# 4     15:49:00  Business       Fort Pierce   West Palm Beach     63.7
# ...        ...       ...               ...               ...      ...
# 1151  13:42:00  Business           Karachi  Unknown Location      3.9
# 1152  15:38:00  Business  Unknown Location  Unknown Location     16.2
# 1153  21:50:00  Business        Katunayake           Gampaha      6.4
# 1154  23:51:00  Business           Gampaha         Ilukwatta     48.2
# 1155       NaT       NaN               NaN               NaN  12204.7
#
#               PURPOSE STARTING_TIME        DATE
# 0      Meal/Entertain      21:11:00  2016-01-01
# ...

# %%
df.isnull()

# df.isnull().sum()



# df['START'].unique()
# df['START'].value_counts()


# df['START'].unique()


#13
# df['STOP'].unique()
# df['STOP'].value_counts()

# df.sort_values(['START'])
# Out:
#       END_TIME  CATEGORY  START   STOP     KM  PURPOSE  STARTING_TIME   DATE
# 0        False     False  False  False  False    False          False  False
# 1        False     False  False  False  False     True          False  False
# 2        False     False  False  False  False    False          False  False
# 3        False     False  False  False  False    False          False  False
# 4        False     False  False  False  False    False          False  False
# ...        ...       ...    ...    ...    ...      ...            ...    ...
# 1151     False     False  False  False  False    False          False  False
# 1152     False     False  False  False  False    False          False  False
# 1153     False     False  False  False  False    False          False  False
# 1154     False     False  False  False  False    False          False  False
# 1155      True      True   True   True  False     True           True   True
#
# [1156 rows x 8 columns]

# %%
#6
df.isnull().values.sum()#values will work on dataframe either to find NAN values or not null values
#count():- when ever we need to find the count of non-(null/NaN) values then will  will use count()
# Out:
# 509

# %%
df['START'].isnull().values.sum()
# Out:
# 1

# %%
df['START'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
df['START'].value_counts()
# Out:
# START
# Cary                 201
# Unknown Location     148
# Morrisville           85
# Whitebridge           68
# Islamabad             57
#                     ...
# Ridgeland              1
# Daytona Beach          1
# Sky Lake               1
# Sand Lake Commons      1
# Gampaha                1
# Name: count, Length: 176, dtype: int64

# %%
#17
dff= pd.DataFrame(df.groupby(['START','STOP']).size())
dff
# Out:
#                                    0
# START         STOP
# Agnew         Agnew                1
#               Cory                 1
#               Renaissance          2
# Almond        Bryson City          1
# Apex          Apex                 2
# ...                               ..
# Whitebridge   Wayne Ridge          4
#               Westpark Place      14
#               Whitebridge          7
#               Williamsburg Manor   1
# Winston Salem Asheville            1
#
# [361 rows x 1 columns]

# %%
#12
s=df['START'].dropna().unique()
len(s)
# Out:
# 176

# %%
# 14
df[df['START']=='San Francisco']
# (df['START']=='San Francisco').value_counts()
# Out:
#      END_TIME  CATEGORY          START        STOP    KM          PURPOSE  \
# 362  15:06:00  Business  San Francisco   Palo Alto  20.5  Between Offices
# 440  16:39:00  Business  San Francisco  Emeryville  11.6          Meeting
# 836  14:31:00  Business  San Francisco    Berkeley  10.8              NaN
# 917  19:57:00  Business  San Francisco    Berkeley  13.2  Between Offices
# 919  12:49:00  Business  San Francisco    Berkeley  11.3          Meeting
# 927  19:17:00  Business  San Francisco     Oakland  12.7   Customer Visit
# 933  15:22:00  Business  San Francisco     Oakland   9.9   Temporary Site
# 966  21:00:00  Business  San Francisco    Berkeley  11.8   Temporary Site
#
#     STARTING_TIME        DATE
# 362      14:39:00  2016-05-09
# 440      16:09:00  2016-06-14
# 836      14:02:00  2016-10-19
# 917      19:17:00  2016-11-07
# 919      12:16:00  2016-11-08
# 927      18:40:00  2016-11-09
# 933      15:17:00  2016-11-10
# 966      20:44:00  2016-11-15

# %%
dff=df.pivot_table(values=['KM'],index=['CATEGORY'])
dff
# sns.heatmap(dff,annot=True,linewidth=0.2)
# Out:
#                  KM
# CATEGORY
# Business  10.655844
# Personal   9.320779

# %%
df['CATEGORY'].value_counts()

# %%
#19
plt.figure(figsize=(15,5),facecolor='r')
s=sns.barplot(x='PURPOSE',y='KM',data=df,hue='PURPOSE')
for i in s.containers:
  s.bar_label(i)
  plt.title('PURPOSE VS DISTANCE',color='black')

# %%
# 20
plt.figure(figsize=(15,4))
dff=pd.DataFrame(df['KM'].groupby(df['PURPOSE']).sum())
a=sns.barplot(data=dff,x='PURPOSE',y='KM')
for i in a.containers:
  a.bar_label(i)

# %%
#21
a=sns.countplot(x='CATEGORY',data=df,hue='CATEGORY',palette='dark:HOTPINK')
for i in a.containers:
  a.bar_label(i)

# %%
df.groupby('START').value_counts()

# %%
a=sns.countplot(x='START',data=df,hue='START',palette='dark:blue')
for i in a.containers:
  a.bar_label(i)

# %%
df.groupby('START').value_counts()

# %%
a=sns.countplot(x='STOP',data=df,hue='STOP',palette='dark:blue')
for i in a.containers:
  a.bar_label(i)

# %%
#for what purpose mostly passengers  are choosing uberdrive.
plt.figure(figsize=(15,8))
sns.countplot(data=df,x='PURPOSE',hue='CATEGORY')

# %%
#22
df['CATEGORY'].value_counts()
print(1078/(1078+77),77/(1078+77))
# Out:
# 0.9333333333333333 0.06666666666666667

# %%
df['HOURS']=['	STARTING_TIME']
data=pd.cut(df['HOUR'])

# %% [markdown]
# insigts
#
# I analyzed that most trips are for business purposes, with Meeting and Customer Visit being the most frequent reasons. The majority of trips occur within Fort Pierce, and peak travel times are during weekday afternoons,
#
# about dataset:- "This dataset contains Uber trip details, including start and end times, locations, miles traveled, and purposes.
#
# The goal of this project was to analyza Uber rides data to identify patterns, optimize operations, and improve customer satisfaction. Specifically, we focused on:
#
# Identifying peak usage hours. Analyzing ride durations and distances. Understanding revenue patterns across regions. Proposing actionable insights to enhance service efficiency. The dataset consisted of: Time Range: One year of Uber rides data. Features: Date, time, pickup and drop-off locations, fare amount, distance, payment methods, and user ratings. Data source: Publicly available Uber dataset on Kaggle or another open source.
#
# Data Quality Issues: Inconsistent date formats (01-01-2016 vs. 12/31/2016). Missing location names Unknown Location. Missing PURPOSE
#
# values -10% of the data.
#
# actions I would recommend using these insights to optimize driver availability during peak times, focus on frequently traveled routes, and address data gaps like Unknown Location to improve data quality for future analysis."
